# %% [markdown]
# # Machine Learning CO<sub>2</sub> Working Capacity of MOFs

# %% [markdown]
# โดย รังสิมันต์ เกษแก้ว <br>
# มหาวิทยาลัยแห่งซูริค <br>
# E-mail: rangsiman1993@gmail.com

# %% [markdown]
# ## 0. Import packages

# %%
# import standard scientific libraries
import os
import math
import numpy as np
import pandas as pd

# import ML models from scikit-learn
from sklearn.linear_model import LinearRegression
from sklearn.kernel_ridge import KernelRidge
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn import svm
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## 1. Import the data

# %%
pd.set_option('max_columns', None)
pd.set_option("display.precision", 8)

dataset = "./"

# %% [markdown]
# เนื่องจากในโปรเจ็คนี้เป็นการสาธิตการรัน Machine Learning ดังนั้นจึงจะขอดึงข้อมูล MOFs แค่ 20,000 โครงสร้างแรกเท่านั้น !!!

# %%
train = pd.read_csv(dataset + "train.csv")[:20000]
train.shape
# Out:
# (20000, 14)

# %%
train.head()
# Out:
#       MOFname  volume [A^3]   weight [u]  surface_area [m^2/g]  void_fraction  \
# 0  mof_unit_1   1116.667429   875.240600                  0.00        0.07899
# 1  mof_unit_2   2769.503842  2211.697211                603.61        0.13794
# 2  mof_unit_3   1089.818728   773.687960                788.50        0.14874
# 3  mof_unit_4   2205.198301  1304.638720               1441.53        0.21814
# 4  mof_unit_5   1137.800963   901.736120                  0.00        0.07778
#
#    void_volume [cm^3/g] functional_groups  metal_linker  organic_linker1  \
# 0                0.0607          COOH-OEt             3                4
# 1                0.1040             F-OMe            10               44
# 2                0.1262          OMe-COOH             2               22
# 3                0.2220            H-SO3H             9               17
# 4                0.0591           NHMe-OH             2                1
#
#    organic_linker2 topology  CO2/N2_selectivity  \
# 0               11      pcu         22.86416611
# 1               57      etb         33.61678033
# 2               24      pcu         19.26372569
# 3               24      sra         25.70137692
# 4               22      pcu         30.00183795
#
#    heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]  CO2_working_capacity [mL/g]
# 0                                       6.786041                 105.28450172
# 1                                       7.147286                 101.22477418
# 2                                       6.347967                 118.98701075
# 3                                       6.190085                 187.62600450
# 4                                       6.478063                  79.21000066

# %%
feat = list(train.columns.values)
feat = {k: v for k, v in enumerate(feat)}
feat
# Out:
# {0: 'MOFname',
#  1: 'volume [A^3]',
#  2: 'weight [u]',
#  3: 'surface_area [m^2/g]',
#  4: 'void_fraction',
#  5: 'void_volume [cm^3/g]',
#  6: 'functional_groups',
#  7: 'metal_linker',
#  8: 'organic_linker1',
#  9: 'organic_linker2',
#  10: 'topology',
#  11: 'CO2/N2_selectivity',
#  12: 'heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]',
#  13: 'CO2_working_capacity [mL/g]'}

# %% [markdown]
# ## 2. Clean data

# %%
train = train.iloc[:, [1,2,3,4,5,7,8,9,11,12,13]]
train
# Out:
#        volume [A^3]   weight [u]  surface_area [m^2/g]  void_fraction  \
# 0       1116.667429   875.240600                  0.00        0.07899
# 1       2769.503842  2211.697211                603.61        0.13794
# 2       1089.818728   773.687960                788.50        0.14874
# 3       2205.198301  1304.638720               1441.53        0.21814
# 4       1137.800963   901.736120                  0.00        0.07778
# ...             ...          ...                   ...            ...
# 19995   5189.923599  2423.541440               2944.18        0.33672
# 19996  13710.436745  4426.378000               3208.43        0.44798
# 19997   1215.143789   691.014960               2102.05        0.33106
# 19998   1271.408263   713.463760               1818.66        0.22698
# 19999   1646.788340   894.877280               1264.50        0.18770
#
#        void_volume [cm^3/g]  metal_linker  organic_linker1  organic_linker2  \
# 0                    0.0607             3                4               11
# 1                    0.1040            10               44               57
# 2                    0.1262             2               22               24
# 3                    0.2220             9               17               24
# 4                    0.0591             2                1               22
# ...                     ...           ...              ...              ...
# 19995                0.4342            12               11               11
# 19996                0.8356             3                3                3
# 19997                0.3506             3                1               19
# 19998                0.2436             2               12               13
# 19999                0.2080             2               16               19
#
#        CO2/N2_selectivity  heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]  \
# 0             22.86416611                                       6.786041
# 1             33.61678033                                       7.147286
# 2             19.26372569                                       6.347967
# 3             25.70137692                                       6.190085
# 4             30.00183795                                       6.478063
# ...                   ...                                            ...
# 19995          8.85242576                                       4.787996
# 19996         14.80568930                                       4.909318
# 19997         18.93154465                                       5.574042
# 19998         19.42797408                                       5.772102
# 19999         28.19799629                                       6.243139
#
#        CO2_working_capacity [mL/g]
# 0                     105.28450172
# 1                     101.22477418
# 2                     118.98701075
# 3                     187.62600450
# 4                      79.21000066
# ...                            ...
# 19995                  63.35786482
# 19996                  90.66697340
# 19997                  78.37355779
# 19998                 114.99909150
# 19999                 221.49707093
#
# [20000 rows x 11 columns]

# %%
# find rows having NaN
train.isnull().any(axis=0)
# Out:
# volume [A^3]                                     False
# weight [u]                                       False
# surface_area [m^2/g]                             False
# void_fraction                                    False
# void_volume [cm^3/g]                             False
# metal_linker                                     False
# organic_linker1                                  False
# organic_linker2                                  False
# CO2/N2_selectivity                               False
# heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]    False
# CO2_working_capacity [mL/g]                      False
# dtype: bool

# %%
# find row having inf
np.isinf(train).any(axis=0)
# Out:
# volume [A^3]                                     False
# weight [u]                                       False
# surface_area [m^2/g]                             False
# void_fraction                                    False
# void_volume [cm^3/g]                             False
# metal_linker                                     False
# organic_linker1                                  False
# organic_linker2                                  False
# CO2/N2_selectivity                               False
# heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]    False
# CO2_working_capacity [mL/g]                      False
# dtype: bool

# %% [markdown]
# ## 3. Prepare training and test sets

# %% [markdown]
# Prepare input
# - x_train = train input
# - y_train = train output
# - x_test = test input
# - y_test = test predict

# %%
ratio = 0.8
train_size = math.floor(train.shape[0]*0.8)
test_size = train.shape[0] - train_size
print("dataset size:", train.shape[0])
print("train size:", train_size)
print("test size:", test_size)
# Out:
# dataset size: 20000
# train size: 16000
# test size: 4000

# %%
feat = list(train.columns.values)
feat = {k: v for k, v in enumerate(feat)}
feat
# Out:
# {0: 'volume [A^3]',
#  1: 'weight [u]',
#  2: 'surface_area [m^2/g]',
#  3: 'void_fraction',
#  4: 'void_volume [cm^3/g]',
#  5: 'metal_linker',
#  6: 'organic_linker1',
#  7: 'organic_linker2',
#  8: 'CO2/N2_selectivity',
#  9: 'heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]',
#  10: 'CO2_working_capacity [mL/g]'}

# %%
train.dtypes
# Out:
# volume [A^3]                                     float64
# weight [u]                                       float64
# surface_area [m^2/g]                             float64
# void_fraction                                    float64
# void_volume [cm^3/g]                             float64
# metal_linker                                       int64
# organic_linker1                                    int64
# organic_linker2                                    int64
# CO2/N2_selectivity                               float64
# heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]    float64
# CO2_working_capacity [mL/g]                      float64
# dtype: object

# %%
x_train = train.iloc[0:train_size, :-1].astype(np.float32)
y_train = train.iloc[0:train_size, -1].astype(np.float32)
x_test = train.iloc[train_size:train_size+test_size, :-1].astype(np.float32)
y_true = train.iloc[train_size:train_size+test_size, -1].astype(np.float32)

# %%
x_train.dtypes
# Out:
# volume [A^3]                                     float32
# weight [u]                                       float32
# surface_area [m^2/g]                             float32
# void_fraction                                    float32
# void_volume [cm^3/g]                             float32
# metal_linker                                     float32
# organic_linker1                                  float32
# organic_linker2                                  float32
# CO2/N2_selectivity                               float32
# heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]    float32
# dtype: object

# %%
x_train
# Out:
#         volume [A^3]     weight [u]  surface_area [m^2/g]  void_fraction  \
# 0      1116.66748047   875.24060059            0.00000000     0.07899000
# 1      2769.50390625  2211.69726562          603.60998535     0.13794000
# 2      1089.81872559   773.68798828          788.50000000     0.14873999
# 3      2205.19824219  1304.63867188         1441.53002930     0.21814001
# 4      1137.80090332   901.73614502            0.00000000     0.07778000
# ...              ...            ...                   ...            ...
# 15995  1118.13647461   879.33984375          724.85998535     0.15647000
# 15996  1042.06066895   715.28967285          571.57000732     0.10680000
# 15997  6099.76220703  3157.22558594         2195.46997070     0.36535999
# 15998  3866.07568359  2765.51123047          733.80999756     0.15019999
# 15999  4115.41308594  2219.76660156         1667.66003418     0.36035001
#
#        void_volume [cm^3/g]  metal_linker  organic_linker1  organic_linker2  \
# 0                0.06070000           3.0              4.0             11.0
# 1                0.10400000          10.0             44.0             57.0
# 2                0.12620001           2.0             22.0             24.0
# 3                0.22200000           9.0             17.0             24.0
# 4                0.05910000           2.0              1.0             22.0
# ...                     ...           ...              ...              ...
# 15995            0.11980000           2.0              1.0             12.0
# 15996            0.09370000           3.0             10.0             23.0
# 15997            0.42510000          12.0             25.0             25.0
# 15998            0.12639999           4.0              1.0             24.0
# 15999            0.40230000          10.0             54.0             56.0
#
#        CO2/N2_selectivity  heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]
# 0             22.86416626                                     6.78604078
# 1             33.61677933                                     7.14728594
# 2             19.26372528                                     6.34796715
# 3             25.70137787                                     6.19008493
# 4             30.00183868                                     6.47806311
# ...                   ...                                            ...
# 15995         19.48492050                                     6.61062479
# 15996         32.47252655                                     7.10846806
# 15997         21.63723183                                     5.80341291
# 15998         39.14509964                                     6.60240793
# 15999         11.06140423                                     5.64890385
#
# [16000 rows x 10 columns]

# %% [markdown]
# ## 4. Neural network

# %% [markdown]
# ### 4.1: Feed forward neural network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# 2021-10-06 14:04:43.488154: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-10-06 14:04:43.488194: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
model = Sequential()
model.add(Dense(12, input_dim=(x_train.shape[1]), activation='relu')) # input
model.add(Dense(24, activation='relu')) # hidden 1
model.add(Dense(12, activation='relu')) # hidden 2
model.add(Dense(1, activation='linear')) # output
# Out:
# 2021-10-06 14:04:47.571585: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-06 14:04:47.574211: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-10-06 14:04:47.574231: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-10-06 14:04:47.574249: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-7ac02acf-7324-4951-a962-19eb20207f2c): /proc/driver/nvidia/version does not exist
# 2021-10-06 14:04:47.574487: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-06 14:04:47.574680: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
model.compile(loss='mae', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=88, batch_size=64)
# Out:
# 2021-10-06 14:04:52.768353: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-10-06 14:04:52.776231: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# Epoch 1/88
# 250/250 [==============================] - 1s 935us/step - loss: 189.0491 - accuracy: 0.0000e+00
# Epoch 2/88
# 250/250 [==============================] - 0s 1ms/step - loss: 62.6411 - accuracy: 0.0000e+00
# Epoch 3/88
# 250/250 [==============================] - 0s 850us/step - loss: 55.3138 - accuracy: 0.0000e+00
# Epoch 4/88
# 250/250 [==============================] - 0s 948us/step - loss: 45.8884 - accuracy: 0.0000e+00
# Epoch 5/88
# 250/250 [==============================] - 0s 874us/step - loss: 40.3460 - accuracy: 0.0000e+00
# Epoch 6/88
# 250/250 [==============================] - 0s 897us/step - loss: 38.3065 - accuracy: 0.0000e+00
# Epoch 7/88
# 250/250 [==============================] - 0s 1ms/step - loss: 36.8129 - accuracy: 0.0000e+00
# Epoch 8/88
# 250/250 [==============================] - 0s 848us/step - loss: 35.5182 - accuracy: 0.0000e+00
# Epoch 9/88
# 250/250 [==============================] - 0s 1ms/step - loss: 35.4418 - accuracy: 0.0000e+00
# Epoch 10/88
# 250/250 [==============================] - 0s 1ms/step - loss: 35.0529 - accuracy: 0.0000e+00
# Epoch 11/88
# 250/250 [==============================] - 0s 921us/step - loss: 34.6271 - accuracy: 0.0000e+00
# Epoch 12/88
# 250/250 [==============================] - 0s 859us/step - loss: 34.8330 - accuracy: 0.0000e+00
# Epoch 13/88
# 250/250 [==============================] - 0s 970us/step - loss: 34.7137 - accuracy: 0.0000e+00
# Epoch 14/88
# 250/250 [==============================] - 0s 1ms/step - loss: 33.5062 - accuracy: 0.0000e+00
# Epoch 15/88
# 250/250 [==============================] - 0s 1ms/step - loss: 33.9541 - accuracy: 0.0000e+00
# Epoch 16/88
# 250/250 [==============================] - 0s 1ms/step - loss: 34.8740 - accuracy: 0.0000e+00
# Epoch 17/88
# 250/250 [==============================] - 0s 912us/step - loss: 34.1352 - accuracy: 0.0000e+00
# Epoch 18/88
# 250/250 [==============================] - 0s 861us/step - loss: 33.7568 - accuracy: 0.0000e+00
# Epoch 19/88
# 250/250 [==============================] - 0s 883us/step - loss: 33.1988 - accuracy: 0.0000e+00
# Epoch 20/88
# 250/250 [==============================] - 0s 850us/step - loss: 33.8575 - accuracy: 0.0000e+00
# Epoch 21/88
# 250/250 [==============================] - 0s 977us/step - loss: 33.4802 - accuracy: 0.0000e+00
# Epoch 22/88
# 250/250 [==============================] - 0s 1ms/step - loss: 33.0735 - accuracy: 0.0000e+00
# Epoch 23/88
# 250/250 [==============================] - 0s 910us/step - loss: 33.1553 - accuracy: 0.0000e+00
# Epoch 24/88
# 250/250 [==============================] - 0s 842us/step - loss: 32.6908 - accuracy: 0.0000e+00
# Epoch 25/88
# 250/250 [==============================] - 0s 936us/step - loss: 34.1539 - accuracy: 0.0000e+00
# Epoch 26/88
# 250/250 [==============================] - 0s 1ms/step - loss: 33.0402 - accuracy: 0.0000e+00
# Epoch 27/88
# 250/250 [==============================] - 0s 881us/step - loss: 32.8176 - accuracy: 0.0000e+00
# Epoch 28/88
# 250/250 [==============================] - 0s 845us/step - loss: 32.8979 - accuracy: 0.0000e+00
# Epoch 29/88
# 250/250 [==============================] - 0s 892us/step - loss: 32.5663 - accuracy: 0.0000e+00
# Epoch 30/88
# 250/250 [==============================] - 0s 1ms/step - loss: 33.3608 - accuracy: 0.0000e+00
# Epoch 31/88
# 250/250 [==============================] - 0s 969us/step - loss: 32.6308 - accuracy: 0.0000e+00
# Epoch 32/88
# 250/250 [==============================] - 0s 948us/step - loss: 32.7579 - accuracy: 0.0000e+00
# Epoch 33/88
# 250/250 [==============================] - 0s 912us/step - loss: 32.2421 - accuracy: 0.0000e+00
# Epoch 34/88
# 250/250 [==============================] - 0s 928us/step - loss: 33.2982 - accuracy: 0.0000e+00
# Epoch 35/88
# 250/250 [==============================] - 0s 988us/step - loss: 33.0776 - accuracy: 0.0000e+00
# Epoch 36/88
# 250/250 [==============================] - 0s 839us/step - loss: 32.4596 - accuracy: 0.0000e+00
# Epoch 37/88
# 250/250 [==============================] - 0s 879us/step - loss: 32.8431 - accuracy: 0.0000e+00
# Epoch 38/88
# 250/250 [==============================] - 0s 921us/step - loss: 32.6923 - accuracy: 0.0000e+00
# Epoch 39/88
# 250/250 [==============================] - 0s 886us/step - loss: 32.5341 - accuracy: 0.0000e+00
# Epoch 40/88
# 250/250 [==============================] - 0s 938us/step - loss: 32.7730 - accuracy: 0.0000e+00
# Epoch 41/88
# 250/250 [==============================] - 0s 849us/step - loss: 32.9051 - accuracy: 0.0000e+00
# Epoch 42/88
# 250/250 [==============================] - 0s 920us/step - loss: 32.3529 - accuracy: 0.0000e+00
# Epoch 43/88
# 250/250 [==============================] - 0s 862us/step - loss: 33.0401 - accuracy: 0.0000e+00
# Epoch 44/88
# 250/250 [==============================] - 0s 884us/step - loss: 32.9338 - accuracy: 0.0000e+00
# Epoch 45/88
# 250/250 [==============================] - 0s 848us/step - loss: 32.9886 - accuracy: 0.0000e+00
# Epoch 46/88
# 250/250 [==============================] - 0s 890us/step - loss: 32.5850 - accuracy: 0.0000e+00
# Epoch 47/88
# 250/250 [==============================] - 0s 910us/step - loss: 32.5952 - accuracy: 0.0000e+00
# Epoch 48/88
# 250/250 [==============================] - 0s 867us/step - loss: 32.4909 - accuracy: 0.0000e+00
# Epoch 49/88
# 250/250 [==============================] - 0s 905us/step - loss: 32.3591 - accuracy: 0.0000e+00
# Epoch 50/88
# 250/250 [==============================] - 0s 862us/step - loss: 32.8673 - accuracy: 0.0000e+00
# Epoch 51/88
# 250/250 [==============================] - 0s 1ms/step - loss: 32.0144 - accuracy: 0.0000e+00
# Epoch 52/88
# 250/250 [==============================] - 0s 859us/step - loss: 32.1639 - accuracy: 0.0000e+00
# Epoch 53/88
# 250/250 [==============================] - 0s 984us/step - loss: 32.9299 - accuracy: 0.0000e+00
# Epoch 54/88
# 250/250 [==============================] - 0s 850us/step - loss: 32.7273 - accuracy: 0.0000e+00
# Epoch 55/88
# 250/250 [==============================] - 0s 896us/step - loss: 32.4320 - accuracy: 0.0000e+00
# Epoch 56/88
# 250/250 [==============================] - 0s 1ms/step - loss: 31.9984 - accuracy: 0.0000e+00
# Epoch 57/88
# 250/250 [==============================] - 0s 1ms/step - loss: 32.3200 - accuracy: 0.0000e+00
# Epoch 58/88
# 250/250 [==============================] - 0s 1ms/step - loss: 32.0439 - accuracy: 0.0000e+00
# Epoch 59/88
# 250/250 [==============================] - 0s 930us/step - loss: 32.3766 - accuracy: 0.0000e+00
# Epoch 60/88
# 250/250 [==============================] - 0s 914us/step - loss: 32.6992 - accuracy: 0.0000e+00
# Epoch 61/88
# 250/250 [==============================] - 0s 911us/step - loss: 31.4944 - accuracy: 0.0000e+00
# Epoch 62/88
# 250/250 [==============================] - 0s 862us/step - loss: 33.0485 - accuracy: 0.0000e+00
# Epoch 63/88
# 250/250 [==============================] - 0s 913us/step - loss: 32.5620 - accuracy: 0.0000e+00
# Epoch 64/88
# 250/250 [==============================] - 0s 1ms/step - loss: 32.0496 - accuracy: 0.0000e+00
# Epoch 65/88
# 250/250 [==============================] - 0s 964us/step - loss: 32.2269 - accuracy: 0.0000e+00
# Epoch 66/88
# 250/250 [==============================] - 0s 846us/step - loss: 32.4833 - accuracy: 0.0000e+00
# Epoch 67/88
# 250/250 [==============================] - 0s 899us/step - loss: 31.6293 - accuracy: 0.0000e+00
# Epoch 68/88
# 250/250 [==============================] - 0s 1ms/step - loss: 32.2569 - accuracy: 0.0000e+00
# Epoch 69/88
# 250/250 [==============================] - 0s 975us/step - loss: 31.5724 - accuracy: 0.0000e+00
# Epoch 70/88
# 250/250 [==============================] - 0s 911us/step - loss: 31.7817 - accuracy: 0.0000e+00
# Epoch 71/88
# 250/250 [==============================] - 0s 897us/step - loss: 31.9459 - accuracy: 0.0000e+00
# Epoch 72/88
# 250/250 [==============================] - 0s 903us/step - loss: 31.7711 - accuracy: 0.0000e+00
# Epoch 73/88
# 250/250 [==============================] - 0s 1ms/step - loss: 31.9707 - accuracy: 0.0000e+00
# Epoch 74/88
# 250/250 [==============================] - 0s 932us/step - loss: 32.1949 - accuracy: 0.0000e+00
# Epoch 75/88
# 250/250 [==============================] - 0s 917us/step - loss: 31.9965 - accuracy: 0.0000e+00
# Epoch 76/88
# 250/250 [==============================] - 0s 914us/step - loss: 32.1416 - accuracy: 0.0000e+00
# Epoch 77/88
# 250/250 [==============================] - 0s 868us/step - loss: 31.9493 - accuracy: 0.0000e+00
# Epoch 78/88
# 250/250 [==============================] - 0s 997us/step - loss: 32.3410 - accuracy: 0.0000e+00
# Epoch 79/88
# 250/250 [==============================] - 0s 972us/step - loss: 31.7097 - accuracy: 0.0000e+00
# Epoch 80/88
# 250/250 [==============================] - 0s 906us/step - loss: 31.5861 - accuracy: 0.0000e+00
# Epoch 81/88
# 250/250 [==============================] - 0s 881us/step - loss: 31.8867 - accuracy: 0.0000e+00
# Epoch 82/88
# 250/250 [==============================] - 0s 1ms/step - loss: 31.7965 - accuracy: 0.0000e+00
# Epoch 83/88
# 250/250 [==============================] - 0s 879us/step - loss: 32.5897 - accuracy: 0.0000e+00
# Epoch 84/88
# 250/250 [==============================] - 0s 1ms/step - loss: 31.4679 - accuracy: 0.0000e+00
# Epoch 85/88
# 250/250 [==============================] - 0s 900us/step - loss: 31.5138 - accuracy: 0.0000e+00
# Epoch 86/88
# 250/250 [==============================] - 0s 873us/step - loss: 31.3604 - accuracy: 0.0000e+00
# Epoch 87/88
# 250/250 [==============================] - 0s 976us/step - loss: 32.5367 - accuracy: 0.0000e+00
# Epoch 88/88
# 250/250 [==============================] - 0s 904us/step - loss: 31.9740 - accuracy: 0.0000e+00

# %% [markdown]
# <details>
# <summary> <font color='green'>Click here for some more information about hyperparaper of neural network</font></summary>
# We use MAE as a loss function in the neural network but we use LMAE as a metric in our competition. Is this reasonable?
# </details>

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[179.12062 ],
#        [ 79.922264],
#        [341.51205 ],
#        ...,
#        [105.396   ],
#        [121.42011 ],
#        [186.655   ]], dtype=float32)

# %%
log_mae = np.log(mean_absolute_error(y_pred, y_true))
log_mae
# Out:
# 3.4628491

# %% [markdown]
# ## 4.2 Customization

# %%
import tensorflow.keras.backend as kb

def custom_loss(y_actual, y_pred): 
    custom_loss=tf.experimental.numpy.log10(kb.sum(kb.abs(y_actual - y_pred)) / y_actual.shape[0])
    return custom_loss

# %%
model.compile(loss=custom_loss, optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=60, verbose=0, batch_size=64)

# %%
# predict
y_pred = model.predict(x_test)
# evaluate error
log_mae = np.log(mean_absolute_error(y_pred, y_true))
log_mae
# Out:
# 3.4239626

# %% [markdown]
# ## 5. Predicting CO<sub>2</sub> WC

# %% [markdown]
# ### Import pretest and proprocessing
#
# Today we will prepare a submission file for pretest set for the phase 1 (Development).

# %%
pretest = pd.read_csv(dataset + "pretest.csv")
pretest.shape
# Out:
# (2000, 13)

# %%
col = ["functional_groups", "topology"]
for i in col:
    pretest[i] = pretest[i].astype("category").cat.codes

pretest.dtypes
# Out:
# MOFname                                           object
# volume [A^3]                                     float64
# weight [u]                                       float64
# surface_area [m^2/g]                             float64
# void_fraction                                    float64
# void_volume [cm^3/g]                             float64
# functional_groups                                  int16
# metal_linker                                       int64
# organic_linker1                                    int64
# organic_linker2                                    int64
# topology                                            int8
# CO2/N2_selectivity                               float64
# heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]    float64
# dtype: object

# %%
pretest
# Out:
#                     MOFname  volume [A^3]   weight [u]  surface_area [m^2/g]  \
# 0        mof_unit_pretest_1   6288.293858  2271.687140               4148.48
# 1        mof_unit_pretest_2   1790.506437   887.747320               2191.34
# 2        mof_unit_pretest_3   2348.969203  1239.765880               2030.88
# 3        mof_unit_pretest_4   2941.571525  1147.951400               3587.13
# 4        mof_unit_pretest_5    705.397601   643.270740                  0.00
# ...                     ...           ...          ...                   ...
# 1995  mof_unit_pretest_1996   5111.109714  1578.082220               3630.31
# 1996  mof_unit_pretest_1997    911.269336   481.279680               2546.02
# 1997  mof_unit_pretest_1998   4236.596494  1127.792600               4296.42
# 1998  mof_unit_pretest_1999  22861.645381  3492.712720               6252.01
# 1999  mof_unit_pretest_2000   1959.675947  1725.765236                  0.00
#
#       void_fraction  void_volume [cm^3/g]  functional_groups  metal_linker  \
# 0           0.41225                0.6872                305             4
# 1           0.30231                0.3672                149             2
# 2           0.28533                0.3256                371             3
# 3           0.41963                0.6475                 91             2
# 4           0.07060                0.0466                 65             3
# ...             ...                   ...                ...           ...
# 1995        0.58981                1.1504                 49             2
# 1996        0.36132                0.4120                 26             2
# 1997        0.60298                1.3641                143             2
# 1998        0.75732                2.9852                186             2
# 1999        0.02102                0.0144                179            10
#
#       organic_linker1  organic_linker2  topology  CO2/N2_selectivity  \
# 0                   7               27         0         14.04879074
# 1                   4               26         5         20.21722169
# 2                  18               22         5         33.10866151
# 3                   8               15         5         12.80056168
# 4                  10               22         5         23.39561652
# ...               ...              ...       ...                 ...
# 1995                1               14         4          4.77869779
# 1996               10               20         5          6.88338750
# 1997                7               20         5          5.27073403
# 1998                6               11         4          3.17291438
# 1999               47               50         2          9.70460373
#
#       heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]
# 0                                          5.604779
# 1                                          6.148776
# 2                                          6.164397
# 3                                          5.164957
# 4                                          7.090687
# ...                                             ...
# 1995                                       3.675003
# 1996                                       3.732121
# 1997                                       3.354425
# 1998                                       2.643592
# 1999                                       7.289342
#
# [2000 rows x 13 columns]

# %% [markdown]
# ### Let's predict and create a submission file
#
# Join the [Codalab competition](https://competitions.codalab.org/competitions/34540) for this course!
#
# Create a `submission.csv` with your predictions to join the competition and upload it to the competition site.

# %%
pretest_pred = model.predict(pretest.iloc[:, [1,2,3,4,5,7,8,9,11,12]])
pretest_pred
# Out:
# array([[ 82.290665],
#        [129.65016 ],
#        [213.65913 ],
#        ...,
#        [ 37.44519 ],
#        [ 42.51303 ],
#        [ 63.10031 ]], dtype=float32)

# %%
submission = pd.DataFrame({
    "id": ["pretest_" + str(i) for i in range(1,2001)],
    "CO2_working_capacity [mL/g]": pretest_pred.T[0]
    })

submission.to_csv("submission.csv", index=False)

# %%
# !ls
# Out:
#  1-neural-network-with-tensorflow.ipynb   test.csv
#  2-neural-network-MOFs.ipynb		  TestSubmission01_0210.zip
#  2-neural-network-MOFs-mon.ipynb	  TestSubmission01_0536.zip
#  best_model_HDF5_format.h5		  TestSubmission03byBank_0210.zip
#  best_model_SavedModel_format		  TestSubmission03byOshi_0683.zip
#  init.ipynb				  train.csv
#  pretest.csv				 'Zero -To-Hero-ML.ipynb'
#  submission.csv				 'Zero -To-Hero-ML-Phase1-Recov.ipynb'

# %%
# %%capture
# !sudo apt-get update
# !sudo apt-get install zip

# %%
# !zip TestSubmission01_0536.zip submission.csv
# Out:
# updating: submission.csv (deflated 66%)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=89ff0356-6e0b-40ab-922e-602a46fe5c41' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
